# %% [markdown]
# <a href="https://colab.research.google.com/github/meharkhanniazi/AI-DataScience-Practice/blob/main/March%2030%2C%202021%20Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
data = pd.read_excel("data.xlsx")

# %%
ourData = pd.DataFrame(data)

# %%
ourData
# Out:
#     Unnamed: 0 365 DataScience RE California Database  ... Unnamed: 25 Unnamed: 26
# 0          NaN                      Practical example  ...         NaN         NaN
# 1          NaN                                    NaN  ...         NaN         NaN
# 2          NaN                                Product  ...         NaN         NaN
# 3          NaN                                     ID  ...    Mortgage      Source
# 4          NaN                                   1030  ...          No     Website
# ..         ...                                    ...  ...         ...         ...
# 266        NaN                                   5044  ...         NaN         NaN
# 267        NaN                                   5047  ...         NaN         NaN
# 268        NaN                                   5048  ...         NaN         NaN
# 269        NaN                                   5050  ...         NaN         NaN
# ...
